# %%
# !pip install pyarrow

# %%
import pandas as pd

vendas = pd.read_parquet('bronze/vendas_zoop_bronze.parquet')
estoques = pd.read_parquet('bronze/estoques_zoop_bronze.parquet')
redes_sociais = pd.read_parquet('bronze/redes_sociais_zoop_bronze.parquet')

# %%
vendas.tail()
# Out:
#       ID_venda  Dia  Mês   Ano   Horario Canal_venda Origem_venda  ID_produto  \
# 9995      9995   19    8  2024  03:36:16  e-commerce     Facebook          24
# 9996      9996   19    8  2024  13:51:58  e-commerce     Facebook          27
# 9997      9997   19    8  2024  15:37:49  e-commerce     Facebook           2
# 9998      9998   19    8  2024  18:39:55  e-commerce     Facebook          22
# 9999      9999   19    8  2024  20:19:40  e-commerce    Instagram           5
#
#                   Produto Categoria_produto  ...  Quantidade  \
# 9995               TV Box       Eletrônicos  ...           2
# 9996  Câmera de segurança       Eletrônicos  ...           2
# 9997   Ventilador de teto  Eletrodomésticos  ...           3
# 9998            Geladeira  Eletrodomésticos  ...           2
# 9999       Liquidificador  Eletrodomésticos  ...           2
#
#        Metodo_pagamento ID_cliente     Nome_cliente Genero_cliente  \
# ...

# %%
estoques.tail()
# Out:
#       ID_estoque  ID_produto               Produto Categoria_produto  \
# 1135        1135          25       Panela_elétrica  Eletrodomésticos
# 1136        1136          26  Ventilador_de_coluna  Eletrodomésticos
# 1137        1137          27   Câmera_de_segurança       Eletrônicos
# 1138        1138          28   Fritadeira_elétrica  Eletrodomésticos
# 1139        1139          29       Máquina_de_café  Eletrodomésticos
#
#             Data   Horario  Quantidade_em_estoque  Quantidade_novos_produtos  \
# 1135  2024/08/01  06:48:00                    364                         32
# 1136  2024/08/01  12:44:00                    374                          7
# 1137  2024/08/01  12:39:00                    334                         14
# 1138  2024/08/01  09:06:00                    363                         40
# 1139  2024/08/01  17:30:00                    439                          7
#
#       Quantidade_vendida
# 1135                  10
# 1136                  13
# ...

# %%
pd.set_option('display.max_colwidth', 100)
redes_sociais.tail()
# Out:
#       ID_social        Data  Influencia_autor   Plataforma  \
# 9995       9995  2024-09-25             84736  X (Twitter)
# 9996       9996  2024-10-07             40628  X (Twitter)
# 9997       9997  2024-09-06             48669     Facebook
# 9998       9998  2024-09-03             22414  X (Twitter)
# 9999       9999  2024-10-06             70450       TikTok
#
#              Nome_produto Categoria_produto  \
# 9995               TV Box       Eletrônicos
# 9996  Câmera de segurança       Eletrônicos
# 9997   Ventilador de teto  Eletrodomésticos
# 9998            Geladeira  Eletrodomésticos
# 9999       Liquidificador  Eletrodomésticos
#
#                                                                                  Comentario
# 9995                           Produto de ótima qualidade! Vale cada centavo. #TVBox Nota 5
# 9996  Frustrado com a compra. Produto muito inferior ao esperado. #Cameradeseguranca Nota 2
# ...
